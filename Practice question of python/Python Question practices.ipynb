# %% [markdown]
# # Lesson 1.2: Python Basics
# ## Topics Covered:
# - Syntax and Semantics
# - Variables and Data Types
# - Basic Operators (Arithmetic, Comparison, Logical)

# %% [markdown]
# ## 1. Syntax and Semantics
#
# **Question 1:** Write a Python program to print "Hello, World!".

# %%
print("Hello,World!")
# Out:
# Hello,World!

# %% [markdown]
# **Question 2:** Write a Python program that takes a user input and prints it.

# %%
User_input=input("Enter the numbers:")
print("Your input:\n",User_input)
# Out:
# Your input:
#  23

# %% [markdown]
# **Question 3:** Write a Python program to check if a number is positive, negative, or zero.

# %%
user_input=int(input("enter the number:"))
if(user_input==0):
    print("Zero")
elif(user_input>=0):
    print("Positive")
else:
    print("Negative")
# Out:
# Negative

# %% [markdown]
# **Question 4:** Write a Python program to find the largest of three numbers.

# %%
Integer=int(input("Enter the 1st number:"))
second_integer=int(input("Enter the 2nd number:"))
third_integer=int(input("Enter the 3rd number:"))
if(Integer>=second_integer and second_integer>=third_integer):
    print("First Number is the largest amongs three",Integer)
elif(second_integer>=Integer and second_integer>=third_integer):
    print("Second Number is the largest amongs three",second_integer)
else:
    print("Third Number is the largest amonga three",third_integer)
# Out:
# Third Number is the largest amonga three 56

# %% [markdown]
# **Question 5:** Write a Python program to calculate the factorial of a number.

# %%
n=int(input("Enter the number:"))
fact=1
for i in range(1,n+1):
    fact=fact*i
    print(fact)
# Out:
# 1
# 2
# 6

# %% [markdown]
# ## 2. Variables and Data Types
#
# **Question 6:** Create variables of different data types: integer, float, string, and boolean. Print their values and types.

# %%
Intger=265
Floating=12.3
list_number=[2,3]
tuple_number=(2,3,4,4)
set_name={2,3,4,3}
dict_name={"Name":"himanshu"}
string_name="string"
boolean_value=True
print(type(Intger),Intger)
print(type(Floating),Floating)
print(type(string_name),string_name)
print(type(boolean_value),boolean_value)
print(type(list_number),list_number)
print(type(tuple_number),tuple_number)
print(type(dict_name),dict_name)
print(type(string_name),string_name)
# Out:
# <class 'int'> 265
# <class 'float'> 12.3
# <class 'str'> string
# <class 'bool'> True
# <class 'list'> [2, 3]
# <class 'tuple'> (2, 3, 4, 4)
# <class 'dict'> {'Name': 'himanshu'}
# <class 'str'> string

# %% [markdown]
# **Question 7:** Write a Python program to swap the values of two variables.

# %% [markdown]
# **ANSWER**:In this code we are seeing that temp is a temporay storage variable which is store the value of a.So,It's store the value of a and b

# %%
# a=int(input("Enter the first Number:"))
# b=int(input("Enter the second Number:"))
# temp=a
# a=b
# b=temp
# print(a)
# print(b)
# Another way my way is that good or not?
a=int(input("Enter the first number"))
b=int(input("Ente the second number"))
print(b,a)
# Out:
# 32
# 23

# %% [markdown]
# **Question 8:** Write a Python program to convert Celsius to Fahrenheit.

# %%
Celcius=int(input("Enter the Celsius you want to convert into the Fahrenheit:\n"))
Fahrenhiet=(Celcius*9/5)+32
print(Fahrenhiet)
# Out:
# 41.0

# %% [markdown]
# **Question 9:** Write a Python program to concatenate two strings.

# %%
First_string="Hello!"
Second_string="Himxhuydv"
third_string=First_string+" "+Second_string
print(third_string)
# Out:
# Hello! Himxhuydv

# %% [markdown]
# **Question 10:** Write a Python program to check if a variable is of a specific data type.

# %%
# x=10
# if(isinstance(x,float)):
#     print("x is float")
# elif(isinstance(x,int)):
#     print("x is int")
# elif(isinstance(x,str)):
#     print("x is string")
# elif(isinstance(x,bool)):
#     print(" x is boolean")
 

# my version
e=23
if (type(e))==float:
    print("e is float datatype")
elif (type(e))==int:
    print("int")
elif type(e)==str:
    print("string")
elif type(e)==bool:
    print("boolean")
else:
    print("unkwon")
# Out:
# int

# %% [markdown]
# ## 3. Basic Operators (Arithmetic, Comparison, Logical)
#
# **Question 11:** Write a Python program to perform arithmetic operations: addition, subtraction, multiplication, and division.

# %%
a=int(input("enter the first number"))
b=int(input("enter the second number"))
print("addition",a+b)
print("Substract",a-b)
print("multiple",a*b)
print("divide",a/b)
# Out:
# addition 5
# Substract -1
# multiple 6
# divide 0.6666666666666666

# %% [markdown]
# **Question 12:** Write a Python program to demonstrate comparison operators: equal to, not equal to, greater than, less than.

# %%
age=int(input("Enter the age:"))
if age<0:
    print("come on bro still using 2nd grade joke")
elif (age>60):
    print("go to the spritual places")
elif (age<=18):
    ("hell nooo go home brother")
elif(age>=18):
    print("adult")
else:
    print("invalid")
# Out:
# adult

# %% [markdown]
# **Question 13:** Write a Python program to demonstrate logical operators: and, or, not.

# %%
# Logical Operators
age=int(input("Enter the age of yours:"))
if age>10 and age<18:
    print("Teenager Pass")
elif age==18 or age>18:
    print("Adult Pass")
if age!=0:
    print("valid")
else:
    print("invalid")
# Out:
# Adult Pass
# valid

# %% [markdown]
# **Question 14:** Write a Python program to calculate the square of a number.

# %% [markdown]
# **ANSWER 14**:
# * **Square**:We just multiply itself the number to find the square.
# * **CUBE**:for the cube we multiply the number thrice.(#but  dont asked here.)
# 2 method to

# %%
n=int(input("Enter the number you want the square"))
#print(n*n)
# another way
result=n**2
print(result)
# Out:
# 529

# %% [markdown]
# **Question 15:** Write a Python program to check if a number is even or odd.

# %% [markdown]
# **ANSWER 15:**
# * **EVEN**:So the number is even when the number is divisible by two and the reminder=0 then it's mean it's an even number.
# * **ODD**:When the number is divide and the reminder!=zero.the only say to get reminnder is zero is divisible by itself.
# We take input from user and then we check the number is divided by two or not if yes then it's *even* number.it not then it's *odd* number.

# %%
even=int(input("Enter the number is even or not "))
if even==0:
    print("both")
elif even%2==0:
    print("Even")
else:
    print("odd")
# Out:
# Even

# %% [markdown]
# **Question 16:** Write a Python program to find the sum of the first n natural numbers.

# %% [markdown]
# **ANSWER 16**:

# %%
Natural_numnber=int(input("Enter the natural number you want the sum"))
nat=0
for i in range(1,Natural_numnber+1):
    nat+=i+i
    print(nat)
# Out:
# 2
# 6
# 12
# 20
# 30
# 42
# 56
# 72
# 90
# 110
# 132
# 156

# %% [markdown]
# **Question 17:** Write a Python program to check if a year is a leap year.

# %%
year=int(input("Enter the total days of the year:\n"))
if year%400==0: # for  2000 and 1600  this year will be detected
    print("leap Year")
elif year%100==0:
    print("Not a leap year")
elif year%4==0: # 1996 ,2004 year will be 
    print("Leap Year")
else:
    print("Not a leap Year")
# Out:
# leap year

# %% [markdown]
# **Question 18:** Write a Python program to reverse a string.

# %%
identity="himxhuydv hi i am a joke"
print(identity[::-1])
# Out:
# ekoj a ma i ih vdyuhxmih

# %% [markdown]
# **Question 19:** Write a Python program to check if a string is a palindrome.

# %%
plaind="dad"  #plaindrome
# plaind="dad mom" #  not plaindrome
print(plaind[::-1])
if plaind==plaind[::-1]:
    print("palindrome")
else:
    print("not palindrome")
# Out:
# dad
# palindrome

# %% [markdown]
# **Question 20:** Write a Python program to sort a list of numbers in ascending order.

# %%
list_1=[2,3,1,42,4,21,42,24,124]
list_1.sort()
print(list_1)
# Out:
# [1, 2, 3, 4, 21, 24, 42, 42, 124]

# %% [markdown]
# **Question 21:** Write a python program to sort a list and store that into a new list in ascending order.

# %% [markdown]
# **Answer:** **Sorted** not is a separate built in function used in create a new list which contain the value of a sorted list.but remember that sorted(*here has to be the list name*).

# %%
ab_1=[1,21,2,31,31,23,2,12312,123,123,5665,43,545,4,64,64,6,554,5]
list_2=sorted(ab_1) 
print(list_2)
